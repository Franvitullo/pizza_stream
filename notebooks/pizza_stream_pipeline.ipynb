# %%
import utils as u
import os
# Load configuration
config = u.load_config()

# %%
# Pizza Stream code
ps_nn = "ps_40"

# %%
# Link del video o ruta local
video_original = os.path.join(config['videos_input_dir'], f"{ps_nn}.mp4")

base_dir = os.path.join(config['vault_path'], config['project_root'])
video_editado = os.path.join(base_dir, ps_nn, f"{ps_nn}.mp4")

# %%
# base_dir is defined in the previous cell from config
# base_dir = ... (replaced by config)

# %%
current_folder = u.crear_carpeta_y_obsidian(ps_nn,
                                            vault_path = config['vault_path'],
                                            root_folder = config['project_root']
                                            )
# Out:
# Ya existía: G:\Mi unidad\Obsidian\0 - Source Material\Frankis Pizza\1_obras\Pizza Stream\ps_39\Pizza stream 39 (ps_39).md
# Ya existía: G:\Mi unidad\Obsidian\0 - Source Material\Frankis Pizza\1_obras\Pizza Stream\ps_40\Pizza stream 40 (ps_40).md

# %%
# Creo carpetas
u.crear_carpetas(
    base_path = current_folder ,
    carpetas = [
        'clips_horizontal',
        'clips_vertical',
        'thumbnails',
        'recursos',
        'videos'
        ]
    )

# %%
# Setup (ejecutar de aca para arriba para crear carpetas, aun no involucra nada de video)

# %%
# Sincroniza audio/video desfasado (en milisegundos)
video_sincronizado = u.sincronizar_audio_video(
                        input_path = video_original,
                        output_path = current_folder + f"\\videos\\{ps_nn}_s.mp4",
                        desfase_ms = 250
                        )
# Out:
# Ejecutando comando de sincronización:
# ffmpeg -i C:\Users\Franki\Videos\ps_39.mkv -itsoffset 0.25 -i C:\Users\Franki\Videos\ps_39.mkv -map 0:v -map 1:a -c copy -y G:\Mi unidad\Obsidian\0 - Source Material\Frankis Pizza\1_obras\Pizza Stream\ps_39\videos\ps_39_s.mp4
# Sincronización completada. Archivo guardado en: G:\Mi unidad\Obsidian\0 - Source Material\Frankis Pizza\1_obras\Pizza Stream\ps_39\videos\ps_39_s.mp4

# %%
# Recortar silencios
video_sin_silencios = u.remove_silence_precise(
                        input_path=video_sincronizado,
                        output_path=current_folder + f"\\videos\\{ps_nn}_sin_silencios.mp4",
                        silence_threshold=-25.0,  # de -20 a -25
                        silence_min_duration=0.5,
                        buffer_start=0.1,   # buffer ANTES del fragmento
                        buffer_end=0.4      # buffer DESPUÉS del fragmento
                )

# %%
# Para ejecutar la primera parte: Pararse acá y ejecutar celdas de arriba

# Antes de seguir, editar el video manualmente 

# Luego de editar y guarda el video con nombre "ps_nn": Pararse acá y ejecutar celdas de abajo para hacer clips

# %%
# Genero clips (tiempo duracion nombre)
clips = """

1:30 30 lavidaeesfacilsalsa1
2:15 45 sanguche
4:15 45 salsa2
4:35 50 alquimia
6:00 20 salenelpan
6:50 35 ciruja
7:30 30 jamoncrudo
7:45 60 marianaenriquez
8:30 40 chacabuco
9:15 35 jamonmelon

"""

# Formateo clips
timeline = u.text_input_clips(clips)

# %%
# Corto clips a partir del editado 
clips_horizontal = u.clips(input_path = video_editado,
                           timeline = timeline,
                           output_path = current_folder + r"\clips_horizontal")
# Out:
# Corte 00: G:\Mi unidad\Obsidian\0 - Source Material\Frankis Pizza\1_obras\Pizza Stream\ps_39\clips_horizontal\00_lavidaeesfacilsalsa1_1m30s_30s.mp4
# Corte 01: G:\Mi unidad\Obsidian\0 - Source Material\Frankis Pizza\1_obras\Pizza Stream\ps_39\clips_horizontal\01_sanguche_2m15s_45s.mp4
# Corte 02: G:\Mi unidad\Obsidian\0 - Source Material\Frankis Pizza\1_obras\Pizza Stream\ps_39\clips_horizontal\02_salsa2_4m15s_45s.mp4
# Corte 03: G:\Mi unidad\Obsidian\0 - Source Material\Frankis Pizza\1_obras\Pizza Stream\ps_39\clips_horizontal\03_alquimia_4m35s_50s.mp4
# Corte 04: G:\Mi unidad\Obsidian\0 - Source Material\Frankis Pizza\1_obras\Pizza Stream\ps_39\clips_horizontal\04_salenelpan_6m00s_20s.mp4
# Corte 05: G:\Mi unidad\Obsidian\0 - Source Material\Frankis Pizza\1_obras\Pizza Stream\ps_39\clips_horizontal\05_ciruja_6m50s_35s.mp4
# Corte 06: G:\Mi unidad\Obsidian\0 - Source Material\Frankis Pizza\1_obras\Pizza Stream\ps_39\clips_horizontal\06_jamoncrudo_7m30s_30s.mp4
# Corte 07: G:\Mi unidad\Obsidian\0 - Source Material\Frankis Pizza\1_obras\Pizza Stream\ps_39\clips_horizontal\07_marianaenriquez_7m45s_60s.mp4
# Corte 08: G:\Mi unidad\Obsidian\0 - Source Material\Frankis Pizza\1_obras\Pizza Stream\ps_39\clips_horizontal\08_chacabuco_8m30s_40s.mp4
# Corte 09: G:\Mi unidad\Obsidian\0 - Source Material\Frankis Pizza\1_obras\Pizza Stream\ps_39\clips_horizontal\09_jamonmelon_9m15s_35s.mp4

# %%
# Resumen a vertical
clips_vertical = u.convert_videos_vertical(input_paths = clips_horizontal,
                                         output_dir = current_folder + r"\clips_vertical",
                                         resolution = "1080p",
                                         cut_pixel = 960)
# Out:
# Ejecutando: ffmpeg -i G:\Mi unidad\Obsidian\0 - Source Material\Frankis Pizza\1_obras\Pizza Stream\ps_39\clips_horizontal\00_lavidaeesfacilsalsa1_1m30s_30s.mp4 -filter_complex [0:v]split=2[left][right];[left]crop=w=960:h=1080:x=0:y=0,scale=720:-1,crop=720:640:0:85[lout];[right]crop=w=960:h=1080:x=960:y=0,scale=720:-1,crop=720:640:0:85[rout];[lout]pad=720:650:0:0:color=black[lout_pad];[lout_pad][rout]vstack=2[outv] -map [outv] -map 0:a? -c:v libx264 -c:a copy -y G:\Mi unidad\Obsidian\0 - Source Material\Frankis Pizza\1_obras\Pizza Stream\ps_39\clips_vertical\00_lavidaeesfacilsalsa1_1m30s_30s_vertical.mp4
# Generado → G:\Mi unidad\Obsidian\0 - Source Material\Frankis Pizza\1_obras\Pizza Stream\ps_39\clips_vertical\00_lavidaeesfacilsalsa1_1m30s_30s_vertical.mp4
# Ejecutando: ffmpeg -i G:\Mi unidad\Obsidian\0 - Source Material\Frankis Pizza\1_obras\Pizza Stream\ps_39\clips_horizontal\01_sanguche_2m15s_45s.mp4 -filter_complex [0:v]split=2[left][right];[left]crop=w=960:h=1080:x=0:y=0,scale=720:-1,crop=720:640:0:85[lout];[right]crop=w=960:h=1080:x=960:y=0,scale=720:-1,crop=720:640:0:85[rout];[lout]pad=720:650:0:0:color=black[lout_pad];[lout_pad][rout]vstack=2[outv] -map [outv] -map 0:a? -c:v libx264 -c:a copy -y G:\Mi unidad\Obsidian\0 - Source Material\Frankis Pizza\1_obras\Pizza Stream\ps_39\clips_vertical\01_sanguche_2m15s_45s_vertical.mp4
# Generado → G:\Mi unidad\Obsidian\0 - Source Material\Frankis Pizza\1_obras\Pizza Stream\ps_39\clips_vertical\01_sanguche_2m15s_45s_vertical.mp4
# Ejecutando: ffmpeg -i G:\Mi unidad\Obsidian\0 - Source Material\Frankis Pizza\1_obras\Pizza Stream\ps_39\clips_horizontal\02_salsa2_4m15s_45s.mp4 -filter_complex [0:v]split=2[left][right];[left]crop=w=960:h=1080:x=0:y=0,scale=720:-1,crop=720:640:0:85[lout];[right]crop=w=960:h=1080:x=960:y=0,scale=720:-1,crop=720:640:0:85[rout];[lout]pad=720:650:0:0:color=black[lout_pad];[lout_pad][rout]vstack=2[outv] -map [outv] -map 0:a? -c:v libx264 -c:a copy -y G:\Mi unidad\Obsidian\0 - Source Material\Frankis Pizza\1_obras\Pizza Stream\ps_39\clips_vertical\02_salsa2_4m15s_45s_vertical.mp4
# Generado → G:\Mi unidad\Obsidian\0 - Source Material\Frankis Pizza\1_obras\Pizza Stream\ps_39\clips_vertical\02_salsa2_4m15s_45s_vertical.mp4
# Ejecutando: ffmpeg -i G:\Mi unidad\Obsidian\0 - Source Material\Frankis Pizza\1_obras\Pizza Stream\ps_39\clips_horizontal\03_alquimia_4m35s_50s.mp4 -filter_complex [0:v]split=2[left][right];[left]crop=w=960:h=1080:x=0:y=0,scale=720:-1,crop=720:640:0:85[lout];[right]crop=w=960:h=1080:x=960:y=0,scale=720:-1,crop=720:640:0:85[rout];[lout]pad=720:650:0:0:color=black[lout_pad];[lout_pad][rout]vstack=2[outv] -map [outv] -map 0:a? -c:v libx264 -c:a copy -y G:\Mi unidad\Obsidian\0 - Source Material\Frankis Pizza\1_obras\Pizza Stream\ps_39\clips_vertical\03_alquimia_4m35s_50s_vertical.mp4
# Generado → G:\Mi unidad\Obsidian\0 - Source Material\Frankis Pizza\1_obras\Pizza Stream\ps_39\clips_vertical\03_alquimia_4m35s_50s_vertical.mp4
# Ejecutando: ffmpeg -i G:\Mi unidad\Obsidian\0 - Source Material\Frankis Pizza\1_obras\Pizza Stream\ps_39\clips_horizontal\04_salenelpan_6m00s_20s.mp4 -filter_complex [0:v]split=2[left][right];[left]crop=w=960:h=1080:x=0:y=0,scale=720:-1,crop=720:640:0:85[lout];[right]crop=w=960:h=1080:x=960:y=0,scale=720:-1,crop=720:640:0:85[rout];[lout]pad=720:650:0:0:color=black[lout_pad];[lout_pad][rout]vstack=2[outv] -map [outv] -map 0:a? -c:v libx264 -c:a copy -y G:\Mi unidad\Obsidian\0 - Source Material\Frankis Pizza\1_obras\Pizza Stream\ps_39\clips_vertical\04_salenelpan_6m00s_20s_vertical.mp4
# Generado → G:\Mi unidad\Obsidian\0 - Source Material\Frankis Pizza\1_obras\Pizza Stream\ps_39\clips_vertical\04_salenelpan_6m00s_20s_vertical.mp4
# Ejecutando: ffmpeg -i G:\Mi unidad\Obsidian\0 - Source Material\Frankis Pizza\1_obras\Pizza Stream\ps_39\clips_horizontal\05_ciruja_6m50s_35s.mp4 -filter_complex [0:v]split=2[left][right];[left]crop=w=960:h=1080:x=0:y=0,scale=720:-1,crop=720:640:0:85[lout];[right]crop=w=960:h=1080:x=960:y=0,scale=720:-1,crop=720:640:0:85[rout];[lout]pad=720:650:0:0:color=black[lout_pad];[lout_pad][rout]vstack=2[outv] -map [outv] -map 0:a? -c:v libx264 -c:a copy -y G:\Mi unidad\Obsidian\0 - Source Material\Frankis Pizza\1_obras\Pizza Stream\ps_39\clips_vertical\05_ciruja_6m50s_35s_vertical.mp4
# Generado → G:\Mi unidad\Obsidian\0 - Source Material\Frankis Pizza\1_obras\Pizza Stream\ps_39\clips_vertical\05_ciruja_6m50s_35s_vertical.mp4
# Ejecutando: ffmpeg -i G:\Mi unidad\Obsidian\0 - Source Material\Frankis Pizza\1_obras\Pizza Stream\ps_39\clips_horizontal\06_jamoncrudo_7m30s_30s.mp4 -filter_complex [0:v]split=2[left][right];[left]crop=w=960:h=1080:x=0:y=0,scale=720:-1,crop=720:640:0:85[lout];[right]crop=w=960:h=1080:x=960:y=0,scale=720:-1,crop=720:640:0:85[rout];[lout]pad=720:650:0:0:color=black[lout_pad];[lout_pad][rout]vstack=2[outv] -map [outv] -map 0:a? -c:v libx264 -c:a copy -y G:\Mi unidad\Obsidian\0 - Source Material\Frankis Pizza\1_obras\Pizza Stream\ps_39\clips_vertical\06_jamoncrudo_7m30s_30s_vertical.mp4
# Generado → G:\Mi unidad\Obsidian\0 - Source Material\Frankis Pizza\1_obras\Pizza Stream\ps_39\clips_vertical\06_jamoncrudo_7m30s_30s_vertical.mp4
# Ejecutando: ffmpeg -i G:\Mi unidad\Obsidian\0 - Source Material\Frankis Pizza\1_obras\Pizza Stream\ps_39\clips_horizontal\07_marianaenriquez_7m45s_60s.mp4 -filter_complex [0:v]split=2[left][right];[left]crop=w=960:h=1080:x=0:y=0,scale=720:-1,crop=720:640:0:85[lout];[right]crop=w=960:h=1080:x=960:y=0,scale=720:-1,crop=720:640:0:85[rout];[lout]pad=720:650:0:0:color=black[lout_pad];[lout_pad][rout]vstack=2[outv] -map [outv] -map 0:a? -c:v libx264 -c:a copy -y G:\Mi unidad\Obsidian\0 - Source Material\Frankis Pizza\1_obras\Pizza Stream\ps_39\clips_vertical\07_marianaenriquez_7m45s_60s_vertical.mp4
# Generado → G:\Mi unidad\Obsidian\0 - Source Material\Frankis Pizza\1_obras\Pizza Stream\ps_39\clips_vertical\07_marianaenriquez_7m45s_60s_vertical.mp4
# Ejecutando: ffmpeg -i G:\Mi unidad\Obsidian\0 - Source Material\Frankis Pizza\1_obras\Pizza Stream\ps_39\clips_horizontal\08_chacabuco_8m30s_40s.mp4 -filter_complex [0:v]split=2[left][right];[left]crop=w=960:h=1080:x=0:y=0,scale=720:-1,crop=720:640:0:85[lout];[right]crop=w=960:h=1080:x=960:y=0,scale=720:-1,crop=720:640:0:85[rout];[lout]pad=720:650:0:0:color=black[lout_pad];[lout_pad][rout]vstack=2[outv] -map [outv] -map 0:a? -c:v libx264 -c:a copy -y G:\Mi unidad\Obsidian\0 - Source Material\Frankis Pizza\1_obras\Pizza Stream\ps_39\clips_vertical\08_chacabuco_8m30s_40s_vertical.mp4
# Generado → G:\Mi unidad\Obsidian\0 - Source Material\Frankis Pizza\1_obras\Pizza Stream\ps_39\clips_vertical\08_chacabuco_8m30s_40s_vertical.mp4
# Ejecutando: ffmpeg -i G:\Mi unidad\Obsidian\0 - Source Material\Frankis Pizza\1_obras\Pizza Stream\ps_39\clips_horizontal\09_jamonmelon_9m15s_35s.mp4 -filter_complex [0:v]split=2[left][right];[left]crop=w=960:h=1080:x=0:y=0,scale=720:-1,crop=720:640:0:85[lout];[right]crop=w=960:h=1080:x=960:y=0,scale=720:-1,crop=720:640:0:85[rout];[lout]pad=720:650:0:0:color=black[lout_pad];[lout_pad][rout]vstack=2[outv] -map [outv] -map 0:a? -c:v libx264 -c:a copy -y G:\Mi unidad\Obsidian\0 - Source Material\Frankis Pizza\1_obras\Pizza Stream\ps_39\clips_vertical\09_jamonmelon_9m15s_35s_vertical.mp4
# Generado → G:\Mi unidad\Obsidian\0 - Source Material\Frankis Pizza\1_obras\Pizza Stream\ps_39\clips_vertical\09_jamonmelon_9m15s_35s_vertical.mp4
